# %%
import pandas as pd
# Read the data
df = pd.read_csv("NSDQ100.csv",header = None)
print(df.head())
# Out:
#             0     1      2          3       4           5
# 0  Activision  atvi  0.56%    Tuesday   4-May  4:05 PM ET
# 1       Adobe  adbe  0.99%    Tuesday  22-Jun  4:05 PM ET
# 2    Advanced   amd  3.12%    Tuesday  27-Apr  4:10 PM ET
# 3     Alexion  alxn  0.47%     Monday   3-May  8:00 AM ET
# 4       Align  algn  0.12%  Wednesday  28-Apr  4:00 PM ET

# %%
# Set the column names
df.columns = ["name", "ticker", "weight","earning day" ,"earning date", "earning time"]
print(df.head())
# Out:
#          name ticker weight earning day earning date earning time
# 0  Activision   atvi  0.56%     Tuesday        4-May   4:05 PM ET
# 1       Adobe   adbe  0.99%     Tuesday       22-Jun   4:05 PM ET
# 2    Advanced    amd  3.12%     Tuesday       27-Apr   4:10 PM ET
# 3     Alexion   alxn  0.47%      Monday        3-May   8:00 AM ET
# 4       Align   algn  0.12%   Wednesday       28-Apr   4:00 PM ET

# %% [markdown]
# # Task-1

# %%
# Exclude all records(companies) whose earning date is before today. (Example: if the earning day is 15 of Jan and today is 20 of Jan, then do not include the record)
import datetime
# Today's Date
today = datetime.datetime.now()
# Convert the earning date string to datetime and filter the recods
df["earning datetime"] = pd.to_datetime(df['earning date'], format="%d-%b").apply(lambda x:x.replace(year=today.year))
excluded_df=df[df["earning datetime"]<today]
result_df = excluded_df.drop("earning datetime",axis =1)
print(result_df.head())
# Out:
#          name ticker weight earning day earning date earning time
# 0  Activision   atvi  0.56%     Tuesday        4-May   4:05 PM ET
# 2    Advanced    amd  3.12%     Tuesday       27-Apr   4:10 PM ET
# 3     Alexion   alxn  0.47%      Monday        3-May   8:00 AM ET
# 4       Align   algn  0.12%   Wednesday       28-Apr   4:00 PM ET
# 5    Alphabet   goog  1.11%     Tuesday       27-Apr   4:15 PM ET

# %%
# Group all companies by same earning date
# convert weight string to numeric value
import warnings
warnings.filterwarnings("ignore")
excluded_df["weight"] = excluded_df["weight"].str.replace("%","")
excluded_df["weight"] = pd.to_numeric(excluded_df["weight"])
grouped = excluded_df.groupby(by="earning datetime")
# To get accumulative weight, add all values of weights in the group.
accumulated_weights = grouped.agg({"weight":"sum"})
accumulated_weights = accumulated_weights.rename(columns={"weight":"accumulative weight"})
# Group the data in the original dataframe
excluded_df = excluded_df.set_index(["earning datetime","name"])
excluded_df = excluded_df.sort_index()
# Print the accumulated weights for each group
print(accumulated_weights)
# accumulated_weights = accumulated_weights["accumulative weight"]
# Out:
#                   accumulative weight
# earning datetime
# 2021-04-21                       5.45
# 2021-04-22                       6.39
# 2021-04-26                       6.86
# 2021-04-27                      15.18
# 2021-04-28                       9.34
# 2021-04-29                      21.69
# 2021-04-30                       0.73
# 2021-05-03                       0.47
# 2021-05-04                       6.52
# 2021-05-05                       5.42
# 2021-05-06                       6.47
# 2021-05-10                       1.30
# 2021-05-11                       0.16
# 2021-05-17                       6.15
# 2021-05-18                       1.09
# 2021-05-19                       3.60
# 2021-05-20                       2.72
# 2021-05-25                       0.53
# 2021-05-26                       4.31
# 2021-05-27                       4.37
# 2021-05-31                       2.58
# 2021-06-01                       0.37
# 2021-06-02                       2.97
# 2021-06-03                       1.78

# %%
# Keep groups, whose accumulative weight is above or equal to 10%.
filtered_df = excluded_df.copy()
# Join the original data with groups with their accumulated weights
dates = excluded_df.index.get_level_values('earning datetime')
filtered_df['accumulative weight'] = accumulated_weights.loc[dates].values
# Filter by weights
filtered_df = filtered_df[filtered_df["accumulative weight"]>10]
filtered_df["accumulative weight"] = filtered_df["accumulative weight"].apply(lambda x:str(x)+"%")
filtered_df = filtered_df.reset_index()
filtered_df = filtered_df.set_index(["earning datetime","accumulative weight","name"])
print(filtered_df)
# Out:
#                                                 ticker  weight earning day  \
# earning datetime accumulative weight name
# 2021-04-27       15.18%              Advanced      amd    3.12     Tuesday
#                                      Alphabet     goog    1.11     Tuesday
#                                      Alphabet    googl    1.13     Tuesday
#                                      Amgen        amgn    1.44     Tuesday
#                                      Fiserv       fisv    0.15     Tuesday
#                                      Illumina     ilmn    1.26     Tuesday
#                                      Maxim        mxim    1.77     Tuesday
#                                      Microsoft    msft    1.31     Tuesday
#                                      Mondelez     mdlz    0.03     Tuesday
#                                      PACCAR       pcar    1.52     Tuesday
#                                      Starbucks    sbux    0.70     Tuesday
#                                      Texas         txn    1.64     Tuesday
# 2021-04-29       21.69%              Amazon.com   amzn    1.58    Thursday
#                                      BioMarin     bmrn    0.47    Thursday
#                                      Citrix       ctxs    0.85    Thursday
#                                      Comcast     cmcsa    0.48    Thursday
#                                      DexCom       dxcm    2.18    Thursday
#                                      Gilead       gild    1.72    Thursday
#                                      KLA          klac    2.02    Thursday
#                                      Seattle      sgen    2.60    Thursday
#                                      Skyworks     swks    1.71    Thursday
#                                      The           khc    1.47    Thursday
#                                      Vertex       vrtx    1.72    Thursday
#                                      Western       wdc    4.61    Thursday
#                                      Xcel          xel    0.28    Thursday
#
#                                                 earning date earning time
# earning datetime accumulative weight name
# 2021-04-27       15.18%              Advanced         27-Apr   4:10 PM ET
#                                      Alphabet         27-Apr   4:15 PM ET
#                                      Alphabet         27-Apr   4:30 PM ET
#                                      Amgen            27-Apr   4:00 PM ET
#                                      Fiserv           27-Apr   0:00 AM ET
#                                      Illumina         27-Apr   4:05 PM ET
#                                      Maxim            27-Apr   4:00 PM ET
#                                      Microsoft        27-Apr   4:10 PM ET
#                                      Mondelez         27-Apr   4:05 PM ET
#                                      PACCAR           27-Apr   8:00 AM ET
#                                      Starbucks        27-Apr   4:05 PM ET
#                                      Texas            27-Apr   4:00 PM ET
# 2021-04-29       21.69%              Amazon.com       29-Apr   4:00 PM ET
#                                      BioMarin         29-Apr   4:05 PM ET
#                                      Citrix           29-Apr   6:00 AM ET
#                                      Comcast          29-Apr   7:00 AM ET
#                                      DexCom           29-Apr   4:00 PM ET
#                                      Gilead           29-Apr   4:00 PM ET
#                                      KLA              29-Apr   4:05 PM ET
#                                      Seattle          29-Apr   4:00 PM ET
#                                      Skyworks         29-Apr   4:00 PM ET
#                                      The              29-Apr   7:00 AM ET
#                                      Vertex           29-Apr   4:00 PM ET
#                                      Western          29-Apr   4:00 PM ET
#                                      Xcel             29-Apr   6:00 AM ET

# %%
# Order the groups by earning dates and print the result
filtered_df = filtered_df.sort_index(level=1)
result = filtered_df.droplevel("name").index.to_frame(index=False)
result = result.drop_duplicates("earning datetime").reset_index().drop("index",axis=1)
print(result)
# Out:
#   earning datetime accumulative weight
# 0       2021-04-27              15.18%
# 1       2021-04-29              21.69%

# %% [markdown]
# # Task-2

# %%
# a) Rewrite the tasks from threshold part. And this time, include all the data about the groups: name, ticker, weight, earning data, earning time.
task_data = filtered_df.copy()
print(task_data)
# Out:
#                                                 ticker  weight earning day  \
# earning datetime accumulative weight name
# 2021-04-27       15.18%              Advanced      amd    3.12     Tuesday
#                                      Alphabet     goog    1.11     Tuesday
#                                      Alphabet    googl    1.13     Tuesday
#                                      Amgen        amgn    1.44     Tuesday
#                                      Fiserv       fisv    0.15     Tuesday
#                                      Illumina     ilmn    1.26     Tuesday
#                                      Maxim        mxim    1.77     Tuesday
#                                      Microsoft    msft    1.31     Tuesday
#                                      Mondelez     mdlz    0.03     Tuesday
#                                      PACCAR       pcar    1.52     Tuesday
#                                      Starbucks    sbux    0.70     Tuesday
#                                      Texas         txn    1.64     Tuesday
# 2021-04-29       21.69%              Amazon.com   amzn    1.58    Thursday
#                                      BioMarin     bmrn    0.47    Thursday
#                                      Citrix       ctxs    0.85    Thursday
#                                      Comcast     cmcsa    0.48    Thursday
#                                      DexCom       dxcm    2.18    Thursday
#                                      Gilead       gild    1.72    Thursday
#                                      KLA          klac    2.02    Thursday
#                                      Seattle      sgen    2.60    Thursday
#                                      Skyworks     swks    1.71    Thursday
#                                      The           khc    1.47    Thursday
#                                      Vertex       vrtx    1.72    Thursday
#                                      Western       wdc    4.61    Thursday
#                                      Xcel          xel    0.28    Thursday
#
#                                                 earning date earning time
# earning datetime accumulative weight name
# 2021-04-27       15.18%              Advanced         27-Apr   4:10 PM ET
#                                      Alphabet         27-Apr   4:15 PM ET
#                                      Alphabet         27-Apr   4:30 PM ET
#                                      Amgen            27-Apr   4:00 PM ET
#                                      Fiserv           27-Apr   0:00 AM ET
#                                      Illumina         27-Apr   4:05 PM ET
#                                      Maxim            27-Apr   4:00 PM ET
#                                      Microsoft        27-Apr   4:10 PM ET
#                                      Mondelez         27-Apr   4:05 PM ET
#                                      PACCAR           27-Apr   8:00 AM ET
#                                      Starbucks        27-Apr   4:05 PM ET
#                                      Texas            27-Apr   4:00 PM ET
# 2021-04-29       21.69%              Amazon.com       29-Apr   4:00 PM ET
#                                      BioMarin         29-Apr   4:05 PM ET
#                                      Citrix           29-Apr   6:00 AM ET
#                                      Comcast          29-Apr   7:00 AM ET
#                                      DexCom           29-Apr   4:00 PM ET
#                                      Gilead           29-Apr   4:00 PM ET
#                                      KLA              29-Apr   4:05 PM ET
#                                      Seattle          29-Apr   4:00 PM ET
#                                      Skyworks         29-Apr   4:00 PM ET
#                                      The              29-Apr   7:00 AM ET
#                                      Vertex           29-Apr   4:00 PM ET
#                                      Western          29-Apr   4:00 PM ET
#                                      Xcel             29-Apr   6:00 AM ET

# %%
from pytz import timezone
gmt = pytz.timezone('GMT')
et = pytz.timezone('US/Eastern')
task_data["earning time"] = task_data['earning time'].str.replace("0:00 AM ET","12:00 PM ET")
task_data = task_data[(task_data["earning time"] != "After the close")]
task_data["earning_time(gmt)"] = pd.to_datetime(task_data['earning time'], format="%I:%M %p ET").apply(lambda x:x.replace(year=today.year))
task_data= task_data[~task_data["earning_time(gmt)"].isnull()]
task_data["earning_time(gmt)"] = task_data["earning_time(gmt)"].apply(lambda x:x.replace(tzinfo=et).astimezone(gmt))
task_data["earning time"] = task_data["earning_time(gmt)"].apply(lambda x:x.strftime("%I:%M %p GMT"))
task_data = task_data.drop("earning_time(gmt)",axis=1) 
print(task_data)
# Out:
#                                                 ticker  weight earning day  \
# earning datetime accumulative weight name
# 2021-04-27       15.18%              Advanced      amd    3.12     Tuesday
#                                      Alphabet     goog    1.11     Tuesday
#                                      Alphabet    googl    1.13     Tuesday
#                                      Amgen        amgn    1.44     Tuesday
#                                      Fiserv       fisv    0.15     Tuesday
#                                      Illumina     ilmn    1.26     Tuesday
#                                      Maxim        mxim    1.77     Tuesday
#                                      Microsoft    msft    1.31     Tuesday
#                                      Mondelez     mdlz    0.03     Tuesday
#                                      PACCAR       pcar    1.52     Tuesday
#                                      Starbucks    sbux    0.70     Tuesday
#                                      Texas         txn    1.64     Tuesday
# 2021-04-29       21.69%              Amazon.com   amzn    1.58    Thursday
#                                      BioMarin     bmrn    0.47    Thursday
#                                      Citrix       ctxs    0.85    Thursday
#                                      Comcast     cmcsa    0.48    Thursday
#                                      DexCom       dxcm    2.18    Thursday
#                                      Gilead       gild    1.72    Thursday
#                                      KLA          klac    2.02    Thursday
#                                      Seattle      sgen    2.60    Thursday
#                                      Skyworks     swks    1.71    Thursday
#                                      The           khc    1.47    Thursday
#                                      Vertex       vrtx    1.72    Thursday
#                                      Western       wdc    4.61    Thursday
#                                      Xcel          xel    0.28    Thursday
#
#                                                 earning date  earning time
# earning datetime accumulative weight name
# 2021-04-27       15.18%              Advanced         27-Apr  09:10 PM GMT
#                                      Alphabet         27-Apr  09:15 PM GMT
#                                      Alphabet         27-Apr  09:30 PM GMT
#                                      Amgen            27-Apr  09:00 PM GMT
#                                      Fiserv           27-Apr  05:00 PM GMT
#                                      Illumina         27-Apr  09:05 PM GMT
#                                      Maxim            27-Apr  09:00 PM GMT
#                                      Microsoft        27-Apr  09:10 PM GMT
#                                      Mondelez         27-Apr  09:05 PM GMT
#                                      PACCAR           27-Apr  01:00 PM GMT
#                                      Starbucks        27-Apr  09:05 PM GMT
#                                      Texas            27-Apr  09:00 PM GMT
# 2021-04-29       21.69%              Amazon.com       29-Apr  09:00 PM GMT
#                                      BioMarin         29-Apr  09:05 PM GMT
#                                      Citrix           29-Apr  11:00 AM GMT
#                                      Comcast          29-Apr  12:00 PM GMT
#                                      DexCom           29-Apr  09:00 PM GMT
#                                      Gilead           29-Apr  09:00 PM GMT
#                                      KLA              29-Apr  09:05 PM GMT
#                                      Seattle          29-Apr  09:00 PM GMT
#                                      Skyworks         29-Apr  09:00 PM GMT
#                                      The              29-Apr  12:00 PM GMT
#                                      Vertex           29-Apr  09:00 PM GMT
#                                      Western          29-Apr  09:00 PM GMT
#                                      Xcel             29-Apr  11:00 AM GMT

# %%
task_data["AM/PM"] = task_data["earning time"].apply(lambda x:"AM" if "AM" in x else "PM")
task_data = task_data.reset_index()
task_data = task_data.set_index(["earning datetime","accumulative weight","AM/PM","name"]).sort_index()
print(task_data)
# To convert to csv use 
task_data.to_csv("task_2.csv")
# Out:
#                                                       ticker  weight  \
# earning datetime accumulative weight AM/PM name
# 2021-04-27       15.18%              PM    Advanced      amd    3.12
#                                            Alphabet     goog    1.11
#                                            Alphabet    googl    1.13
#                                            Amgen        amgn    1.44
#                                            Fiserv       fisv    0.15
#                                            Illumina     ilmn    1.26
#                                            Maxim        mxim    1.77
#                                            Microsoft    msft    1.31
#                                            Mondelez     mdlz    0.03
#                                            PACCAR       pcar    1.52
#                                            Starbucks    sbux    0.70
#                                            Texas         txn    1.64
# 2021-04-29       21.69%              AM    Citrix       ctxs    0.85
#                                            Xcel          xel    0.28
#                                      PM    Amazon.com   amzn    1.58
#                                            BioMarin     bmrn    0.47
#                                            Comcast     cmcsa    0.48
#                                            DexCom       dxcm    2.18
#                                            Gilead       gild    1.72
#                                            KLA          klac    2.02
#                                            Seattle      sgen    2.60
#                                            Skyworks     swks    1.71
#                                            The           khc    1.47
#                                            Vertex       vrtx    1.72
#                                            Western       wdc    4.61
#
#                                                       earning day  \
# earning datetime accumulative weight AM/PM name
# 2021-04-27       15.18%              PM    Advanced       Tuesday
#                                            Alphabet       Tuesday
#                                            Alphabet       Tuesday
#                                            Amgen          Tuesday
#                                            Fiserv         Tuesday
#                                            Illumina       Tuesday
#                                            Maxim          Tuesday
#                                            Microsoft      Tuesday
#                                            Mondelez       Tuesday
#                                            PACCAR         Tuesday
#                                            Starbucks      Tuesday
#                                            Texas          Tuesday
# 2021-04-29       21.69%              AM    Citrix        Thursday
#                                            Xcel          Thursday
#                                      PM    Amazon.com    Thursday
#                                            BioMarin      Thursday
#                                            Comcast       Thursday
#                                            DexCom        Thursday
#                                            Gilead        Thursday
#                                            KLA           Thursday
#                                            Seattle       Thursday
#                                            Skyworks      Thursday
#                                            The           Thursday
#                                            Vertex        Thursday
#                                            Western       Thursday
#
#                                                       earning date  \
# earning datetime accumulative weight AM/PM name
# 2021-04-27       15.18%              PM    Advanced         27-Apr
#                                            Alphabet         27-Apr
#                                            Alphabet         27-Apr
#                                            Amgen            27-Apr
#                                            Fiserv           27-Apr
#                                            Illumina         27-Apr
#                                            Maxim            27-Apr
#                                            Microsoft        27-Apr
#                                            Mondelez         27-Apr
#                                            PACCAR           27-Apr
#                                            Starbucks        27-Apr
#                                            Texas            27-Apr
# 2021-04-29       21.69%              AM    Citrix           29-Apr
#                                            Xcel             29-Apr
#                                      PM    Amazon.com       29-Apr
#                                            BioMarin         29-Apr
#                                            Comcast          29-Apr
#                                            DexCom           29-Apr
#                                            Gilead           29-Apr
#                                            KLA              29-Apr
#                                            Seattle          29-Apr
#                                            Skyworks         29-Apr
#                                            The              29-Apr
#                                            Vertex           29-Apr
#                                            Western          29-Apr
#
#                                                        earning time
# earning datetime accumulative weight AM/PM name
# 2021-04-27       15.18%              PM    Advanced    09:10 PM GMT
#                                            Alphabet    09:15 PM GMT
#                                            Alphabet    09:30 PM GMT
#                                            Amgen       09:00 PM GMT
#                                            Fiserv      05:00 PM GMT
#                                            Illumina    09:05 PM GMT
#                                            Maxim       09:00 PM GMT
#                                            Microsoft   09:10 PM GMT
#                                            Mondelez    09:05 PM GMT
#                                            PACCAR      01:00 PM GMT
#                                            Starbucks   09:05 PM GMT
#                                            Texas       09:00 PM GMT
# 2021-04-29       21.69%              AM    Citrix      11:00 AM GMT
#                                            Xcel        11:00 AM GMT
#                                      PM    Amazon.com  09:00 PM GMT
#                                            BioMarin    09:05 PM GMT
#                                            Comcast     12:00 PM GMT
#                                            DexCom      09:00 PM GMT
#                                            Gilead      09:00 PM GMT
#                                            KLA         09:05 PM GMT
#                                            Seattle     09:00 PM GMT
#                                            Skyworks    09:00 PM GMT
#                                            The         12:00 PM GMT
#                                            Vertex      09:00 PM GMT
#                                            Western     09:00 PM GMT
